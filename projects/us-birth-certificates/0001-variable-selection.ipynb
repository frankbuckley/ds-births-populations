# %% [markdown]
# # 1. Variable selection

# %%
import duckdb
import os
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

from variables import Variables as vars

plt.style.use('../../notebook.mplstyle')

os.makedirs("./output", exist_ok=True)

# %%
# con.close()
con = duckdb.connect("./data/us_births.db", read_only=True)

# %%
df = con.execute(
    f"""
    SELECT
        b.year,
        COUNT(*) as count_obs,
        COUNT(b.dob_mm) as count_dob_mm,
        COUNT(b.dob_wk) as count_dob_wk,
        COUNT(b.sex) as count_sex,
        COUNT(b.dbwt) as count_dbwt,
        COUNT(b.bwtr12) as count_bwtr12,
        COUNT(b.bwtr4) as count_bwtr4,
        COUNT(b.dwgt_r) as count_dwgt_r,
        COUNT(b.dplural) as count_dplural,
        COUNT(b.setorder_r) as count_setorder_r,
        COUNT(b.bfacil) as count_bfacil,
        COUNT(b.bfacil3) as count_bfacil3,
        COUNT(b.precare) as count_precare,
        COUNT(b.precare5) as count_precare5,
        COUNT(b.combgest) as count_combgest,
        COUNT(b.gestrec10) as count_gestrec10,
        COUNT(b.gestrec3) as count_gestrec3,
        COUNT(b.oegest_comb) as count_oegest_comb,
        COUNT(b.oegest_r10) as count_oegest_r10,
        COUNT(b.oegest_r3) as count_oegest_r3,
        COUNT(b.amnio) as count_amnio,
        COUNT(b.apgar5) as count_apgar5,
        COUNT(b.apgar5r) as count_apgar5r,
        COUNT(b.apgar10) as count_apgar10,
        COUNT(b.apgar10r) as count_apgar10r,
        COUNT(b.ab_aven1) as count_ab_aven1,
        COUNT(b.ab_aven6) as count_ab_aven6,
        COUNT(b.ab_nicu) as count_ab_nicu,
        COUNT(b.ab_surf) as count_ab_surf,
        COUNT(b.ab_anti) as count_ab_anti,
        COUNT(b.ab_seiz) as count_ab_seiz,
        COUNT(b.no_abnorm) as count_no_abnorm,
        COUNT(b.congenit) as count_congenit,
        COUNT(b.ca_anen) as count_ca_anen,
        COUNT(b.ca_mnsb) as count_ca_mnsb,
        COUNT(b.ca_cchd) as count_ca_cchd,
        COUNT(b.ca_cdh) as count_ca_cdh,
        COUNT(b.ca_omph) as count_ca_omph,
        COUNT(b.ca_gast) as count_ca_gast,
        COUNT(b.ca_limb) as count_ca_limb,
        COUNT(b.ca_cleft) as count_ca_cleft,
        COUNT(b.ca_clpal) as count_ca_clpal,
        COUNT(b.ca_disor) as count_ca_disor,
        COUNT(b.ca_hypo) as count_ca_hypo,
        COUNT(b.downs) as count_downs,
        COUNT(b.uca_downs) as count_uca_downs,
        COUNT(b.ca_down) as count_ca_down,
        COUNT(b.ca_downs) as count_ca_downs,
        COUNT(b.ca_down_c) as count_ca_down_c,
        COUNT(b.no_congen) as count_no_congen,
        COUNT(b.m_ht_in) as count_m_ht_in,
        COUNT(b.bmi) as count_bmi,
        COUNT(b.bmi_r) as count_bmi_r,
        COUNT(b.pwgt_r) as count_pwgt_r,
        COUNT(b.wtgain) as count_wtgain,
        COUNT(b.mbstate_rec) as count_mbstate_rec,
        COUNT(b.umbstate) as count_umbstate,
        COUNT(b.xmrstate) as count_xmrstate,
        COUNT(b.mrstate) as count_mrstate,
        COUNT(b.restatus) as count_restatus,
        COUNT(b.umagerpt) as count_umagerpt,
        COUNT(b.mager) as count_mager,
        COUNT(b.dmage) as count_dmage,
        COUNT(b.mager41) as count_mager41,
        COUNT(b.mager14) as count_mager14,
        COUNT(b.mager9) as count_mager9,
        COUNT(b.mage36) as count_mage36,
        COUNT(b.mrace31) as count_mrace31,
        COUNT(b.mrace6) as count_mrace6,
        COUNT(b.mrace15) as count_mrace15,
        COUNT(b.mhisp_r) as count_mhisp_r,
        COUNT(b.mracehisp) as count_mracehisp,
        COUNT(b.mar) as count_mar,
        COUNT(b.mar_p) as count_mar_p,
        COUNT(b.dmar) as count_dmar,
        COUNT(b.dmeduc) as count_dmeduc,
        COUNT(b.meduc) as count_meduc,
        COUNT(b.umeduc) as count_umeduc,
        COUNT(b.meduc6) as count_meduc6,
        COUNT(b.meduc_rec) as count_meduc_rec,
        COUNT(b.dfage) as count_dfage,
        COUNT(b.dfagerpt) as count_dfagerpt,
        COUNT(b.fage11) as count_fage11,
        COUNT(b.fagerpt) as count_fagerpt,
        COUNT(b.fagecomb) as count_fagecomb,
        COUNT(b.fagerec11) as count_fagerec11,
        COUNT(b.frace) as count_frace,
        COUNT(b.fraceimp) as count_fraceimp,
        COUNT(b.fracerec) as count_fracerec,
        COUNT(b.frace31) as count_frace31,
        COUNT(b.frace6) as count_frace6,
        COUNT(b.frace15) as count_frace15,
        COUNT(b.fhispx) as count_fhispx,
        COUNT(b.fhisp_r) as count_fhisp_r,
        COUNT(b.fracehisp) as count_fracehisp,
        COUNT(b.feduc) as count_feduc,
        COUNT(b.bfed) as count_bfed,
        COUNT(b.previs) as count_previs,
        COUNT(b.previs_rec) as count_previs_rec,
        COUNT(b.priorlive) as count_priorlive,
        COUNT(b.priordead) as count_priordead,
        COUNT(b.priorterm) as count_priorterm,
        COUNT(b.lbo) as count_lbo,
        COUNT(b.lbo_rec) as count_lbo_rec,
        COUNT(b.tbo) as count_tbo_rec,
        COUNT(b.tbo_rec) as count_tbo,
        COUNT(b.illb_r) as count_illb_r,
        COUNT(b.illb_r11) as count_illb_r11,
        COUNT(b.ilop_r) as count_ilop_r,
        COUNT(b.ilop_r11) as count_ilop_r11,
        COUNT(b.dllb_yy) as count_dllb_yy,
        COUNT(b.dllb_mm) as count_dllb_mm,
        COUNT(b.pay_rec) as count_pay_rec,
        COUNT(b.wic) as count_wic,
        COUNT(b.rf_pdiab) as count_rf_pdiab,
        COUNT(b.rf_gdiab) as count_rf_gdiab,
        COUNT(b.rf_phype) as count_rf_phype,
        COUNT(b.rf_ghype) as count_rf_ghype,
        COUNT(b.rf_ehype) as count_rf_ehype,
        COUNT(b.rf_ppterm) as count_rf_ppterm,
        COUNT(b.rf_inftr) as count_rf_inftr,
        COUNT(b.rf_fedrg) as count_rf_fedrg,
        COUNT(b.rf_artec) as count_rf_artec,
        COUNT(b.rf_cesar) as count_rf_cesar,
        COUNT(b.rf_cesarn) as count_rf_cesarn,
        COUNT(b.no_risks) as count_no_risks,
        COUNT(b.ld_indl) as count_ld_indl,
        COUNT(b.ld_augm) as count_ld_augm,
        COUNT(b.ld_anes) as count_ld_anes,
        COUNT(b.me_pres) as count_me_pres,
        COUNT(b.me_route) as count_me_route,
        COUNT(b.me_trial) as count_me_trial,
        COUNT(b.rdmeth_rec) as count_rdmeth_rec,
        COUNT(b.dmeth_rec) as count_dmeth_rec,
        COUNT(b.attend) as count_attend,
        COUNT(b.mrace_c) as count_mrace_c,
        COUNT(b.mhisp_c) as count_mhisp_c,
        COUNT(b.mracehisp_c) as count_mracehisp_c,
    FROM us_births as b
    WHERE b.year >= 1989
    GROUP BY b.year
    ORDER BY b.year
    """
).df()
df.to_csv("./output/us_births_variables.csv", index=False)
df
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df = con.execute(
#       2     f"""
#       3     SELECT
#       4         b.year,
#       5         COUNT(*) as count_obs,
#       6         COUNT(b.dob_mm) as count_dob_mm,
#       7         COUNT(b.dob_wk) as count_dob_wk,
#       8         COUNT(b.sex) as count_sex,
#       9         COUNT(b.dbwt) as count_dbwt,
#      10         COUNT(b.bwtr12) as count_bwtr12,
#      11         COUNT(b.bwtr4) as count_bwtr4,
#      12         COUNT(b.dwgt_r) as count_dwgt_r,
#      13         COUNT(b.dplural) as count_dplural,
#      14         COUNT(b.setorder_r) as count_setorder_r,
#      15         COUNT(b.bfacil) as count_bfacil,
#      16         COUNT(b.bfacil3) as count_bfacil3,
#      17         COUNT(b.precare) as count_precare,
#      18         COUNT(b.precare5) as count_precare5,
#      19         COUNT(b.combgest) as count_combgest,
#      20         COUNT(b.gestrec10) as count_gestrec10,
#      21         COUNT(b.gestrec3) as count_gestrec3,
#      22         COUNT(b.oegest_comb) as count_oegest_comb,
#      23         COUNT(b.oegest_r10) as count_oegest_r10,
#      24         COUNT(b.oegest_r3) as count_oegest_r3,
#      25         COUNT(b.amnio) as count_amnio,
#      26         COUNT(b.apgar5) as count_apgar5,
#      27         COUNT(b.apgar5r) as count_apgar5r,
#      28         COUNT(b.apgar10) as count_apgar10,
#      29         COUNT(b.apgar10r) as count_apgar10r,
#      30         COUNT(b.ab_aven1) as count_ab_aven1,
#      31         COUNT(b.ab_aven6) as count_ab_aven6,
#      32         COUNT(b.ab_nicu) as count_ab_nicu,
#      33         COUNT(b.ab_surf) as count_ab_surf,
#      34         COUNT(b.ab_anti) as count_ab_anti,
#      35         COUNT(b.ab_seiz) as count_ab_seiz,
#      36         COUNT(b.no_abnorm) as count_no_abnorm,
#      37         COUNT(b.congenit) as count_congenit,
#      38         COUNT(b.ca_anen) as count_ca_anen,
#      39         COUNT(b.ca_mnsb) as count_ca_mnsb,
#      40         COUNT(b.ca_cchd) as count_ca_cchd,
#      41         COUNT(b.ca_cdh) as count_ca_cdh,
#      42         COUNT(b.ca_omph) as count_ca_omph,
#      43         COUNT(b.ca_gast) as count_ca_gast,
#      44         COUNT(b.ca_limb) as count_ca_limb,
#      45         COUNT(b.ca_cleft) as count_ca_cleft,
#      46         COUNT(b.ca_clpal) as count_ca_clpal,
#      47         COUNT(b.ca_disor) as count_ca_disor,
#      48         COUNT(b.ca_hypo) as count_ca_hypo,
#      49         COUNT(b.downs) as count_downs,
#      50         COUNT(b.uca_downs) as count_uca_downs,
#      51         COUNT(b.ca_down) as count_ca_down,
#      52         COUNT(b.ca_downs) as count_ca_downs,
#      53         COUNT(b.ca_down_c) as count_ca_down_c,
#      54         COUNT(b.no_congen) as count_no_congen,
#      55         COUNT(b.m_ht_in) as count_m_ht_in,
#      56         COUNT(b.bmi) as count_bmi,
#      57         COUNT(b.bmi_r) as count_bmi_r,
#      58         COUNT(b.pwgt_r) as count_pwgt_r,
#      59         COUNT(b.wtgain) as count_wtgain,
#      60         COUNT(b.mbstate_rec) as count_mbstate_rec,
#      61         COUNT(b.umbstate) as count_umbstate,
#      62         COUNT(b.xmrstate) as count_xmrstate,
#      63         COUNT(b.mrstate) as count_mrstate,
#      64         COUNT(b.restatus) as count_restatus,
#      65         COUNT(b.umagerpt) as count_umagerpt,
#      66         COUNT(b.mager) as count_mager,
#      67         COUNT(b.dmage) as count_dmage,
#      68         COUNT(b.mager41) as count_mager41,
#      69         COUNT(b.mager14) as count_mager14,
#      70         COUNT(b.mager9) as count_mager9,
#      71         COUNT(b.mage36) as count_mage36,
#      72         COUNT(b.mrace31) as count_mrace31,
#      73         COUNT(b.mrace6) as count_mrace6,
#      74         COUNT(b.mrace15) as count_mrace15,
#      75         COUNT(b.mhisp_r) as count_mhisp_r,
#      76         COUNT(b.mracehisp) as count_mracehisp,
#      77         COUNT(b.mar) as count_mar,
#      78         COUNT(b.mar_p) as count_mar_p,
#      79         COUNT(b.dmar) as count_dmar,
#      80         COUNT(b.dmeduc) as count_dmeduc,
#      81         COUNT(b.meduc) as count_meduc,
#      82         COUNT(b.umeduc) as count_umeduc,
#      83         COUNT(b.meduc6) as count_meduc6,
#      84         COUNT(b.meduc_rec) as count_meduc_rec,
#      85         COUNT(b.dfage) as count_dfage,
#      86         COUNT(b.dfagerpt) as count_dfagerpt,
#      87         COUNT(b.fage11) as count_fage11,
#      88         COUNT(b.fagerpt) as count_fagerpt,
#      89         COUNT(b.fagecomb) as count_fagecomb,
#      90         COUNT(b.fagerec11) as count_fagerec11,
#      91         COUNT(b.frace) as count_frace,
#      92         COUNT(b.fraceimp) as count_fraceimp,
#      93         COUNT(b.fracerec) as count_fracerec,
#      94         COUNT(b.frace31) as count_frace31,
#      95         COUNT(b.frace6) as count_frace6,
#      96         COUNT(b.frace15) as count_frace15,
#      97         COUNT(b.fhispx) as count_fhispx,
#      98         COUNT(b.fhisp_r) as count_fhisp_r,
#      99         COUNT(b.fracehisp) as count_fracehisp,
#     100         COUNT(b.feduc) as count_feduc,
#     101         COUNT(b.bfed) as count_bfed,
#     102         COUNT(b.previs) as count_previs,
#     103         COUNT(b.previs_rec) as count_previs_rec,
#     104         COUNT(b.priorlive) as count_priorlive,
#     105         COUNT(b.priordead) as count_priordead,
#     106         COUNT(b.priorterm) as count_priorterm,
#     107         COUNT(b.lbo) as count_lbo,
#     108         COUNT(b.lbo_rec) as count_lbo_rec,
#     109         COUNT(b.tbo) as count_tbo_rec,
#     110         COUNT(b.tbo_rec) as count_tbo,
#     111         COUNT(b.illb_r) as count_illb_r,
#     112         COUNT(b.illb_r11) as count_illb_r11,
#     113         COUNT(b.ilop_r) as count_ilop_r,
#     114         COUNT(b.ilop_r11) as count_ilop_r11,
#     115         COUNT(b.dllb_yy) as count_dllb_yy,
#     116         COUNT(b.dllb_mm) as count_dllb_mm,
#     117         COUNT(b.pay_rec) as count_pay_rec,
#     118         COUNT(b.wic) as count_wic,
#     119         COUNT(b.rf_pdiab) as count_rf_pdiab,
#     120         COUNT(b.rf_gdiab) as count_rf_gdiab,
#     121         COUNT(b.rf_phype) as count_rf_phype,
#     122         COUNT(b.rf_ghype) as count_rf_ghype,
#     123         COUNT(b.rf_ehype) as count_rf_ehype,
#     124         COUNT(b.rf_ppterm) as count_rf_ppterm,
#     125         COUNT(b.rf_inftr) as count_rf_inftr,
#     126         COUNT(b.rf_fedrg) as count_rf_fedrg,
#     127         COUNT(b.rf_artec) as count_rf_artec,
#     128         COUNT(b.rf_cesar) as count_rf_cesar,
#     129         COUNT(b.rf_cesarn) as count_rf_cesarn,
#     130         COUNT(b.no_risks) as count_no_risks,
#     131         COUNT(b.ld_indl) as count_ld_indl,
#     132         COUNT(b.ld_augm) as count_ld_augm,
#     133         COUNT(b.ld_anes) as count_ld_anes,
#     134         COUNT(b.me_pres) as count_me_pres,
#     135         COUNT(b.me_route) as count_me_route,
#     136         COUNT(b.me_trial) as count_me_trial,
#     137         COUNT(b.rdmeth_rec) as count_rdmeth_rec,
#     138         COUNT(b.dmeth_rec) as count_dmeth_rec,
#     139         COUNT(b.attend) as count_attend,
#     140         COUNT(b.mrace_c) as count_mrace_c,
#     141         COUNT(b.mhisp_c) as count_mhisp_c,
#     142         COUNT(b.mracehisp_c) as count_mracehisp_c,
#     143     FROM us_births as b
#     144     WHERE b.year >= 1989
#     145     GROUP BY b.year
#     146     ORDER BY b.year
#     147     """
#     148 ).df()
#     149 df.to_csv("./output/us_births_variables.csv", index=False)
#     150 df
#
# BinderException: Binder Error: Table "b" does not have a column named "rf_pdiab"
#
# Candidate bindings: : "f_pay"
#
# LINE 118:         COUNT(b.rf_pdiab) as count_rf_pdiab,
#                         ^
